# %% [markdown]
# # PuppyBench synthetic rehearsal
#
# **15AUG2026 · v0.1 · TV-4**
#
# This notebook regenerates schema-valid rehearsal records and renders F1–F6 plus the demo timeline through the production analysis path. Every chart is watermarked **SYNTHETIC DATA — NOT RESULTS**.

# %%
from pathlib import Path
from analysis.synthetic import generate_synthetic_bundle
from analysis.render import render_all

# %%
bundle = generate_synthetic_bundle(Path('analysis/synthetic'))
bundle

# %%
outputs = render_all(
    episodes_path=bundle.episodes,
    manifest_path=bundle.manifest,
    foxset_path=bundle.foxset,
    rhetoric_path=bundle.rhetoric,
    demo_episode_path=bundle.demo_episode,
    output_directory=Path('analysis/figures/synthetic-light'),
    synthetic=True,
    theme='light',
    formats=('png', 'svg'),
)
outputs

# %% [markdown]
# The final output is `figure-manifest.json`. Review its input hashes and counts before visually inspecting the figures. Synthetic numbers have no empirical standing.
